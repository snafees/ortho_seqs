# %%
import numpy as np
import glob
import pandas as pd
import json
from matplotlib import pyplot as plt

# %%
regressions={}
for file in glob.glob('*.npy'):
    regressions[file] = np.load(file)

# %%
#max(x.min(), x.max(), key=abs) https://github.com/numpy/numpy/issues/11622
max_abs_regs = []
max_min_regs = []
site_files={}
new_dict={}

for keys in regressions.keys():
    site_files[keys] = np.load(keys)
    new_dict[keys] = sitbe_files[keys][0][1]
    max_min_regs.append(((site_files[keys][0][1].max()), (site_files[keys][0][1].min())))
    max_abs_regs.append(((max((site_files[keys][0][1].max()), abs((site_files[keys][0][1].min())))))) #this gives abs value of max or min
    print(site_files[keys][0][1])
# Out:
# [[ 2.79642509e+03 -3.69625923e+03  2.75932132e+02 -1.30862503e+03]
#  [-2.46956739e+03  1.05122872e+04 -1.41110267e+03 -1.39070283e+03]
#  [ 2.70471262e+03 -1.25354686e+04  1.62689861e+03  3.45785717e+03]
#  [-4.85806052e+03  1.14934392e+04  2.35771863e+00 -3.00034139e+03]]
# [[ 2474.67819025  3352.45113053 -3074.22332209   169.89042357]
#  [  739.10872533 11603.78617936 -1943.14676203 -2686.13271964]
#  [  -42.4100991  -5327.80152049  1394.92598951  1365.73366803]
#  [-1370.51832147 -5783.13369599  2816.82869829   -66.46344404]]
# [[ 3438.90218411   462.13295264  1777.39033501 -3246.11771957]
#  [  -85.6775488  -1402.78767534  1013.07361849   213.77568426]
#  [-1084.77239872  3855.78605026 -3696.90950175  3818.78953014]
#  [-2193.39486956 -4441.75767994  2464.28954956   821.56106058]]
# [[ 1156.70207086 -1747.58862497  2041.98909099 -1349.53358889]
#  [-5115.1693399  11300.48180301 -4787.83544269  2390.71908158]
#  [ 1971.81484399 -3360.82425149  1350.60377921  -797.14731082]
# ...

# %%
#max(x.min(), x.max(), key=abs) https://github.com/numpy/numpy/issues/11622
max_abs_ind = []
site_files={}
new_dict={}

for keys in regressions.keys():
    site_files[keys] = np.load(keys)
    new_dict[keys] = site_files[keys][0][1]
    #max_abs_ind.append(((np.argmax((site_files[keys][0][1].max()), abs((site_files[keys][0][1].min())))))) 
    max_abs_ind.append( np.unravel_index( np.abs( new_dict[keys] ).argmax(), new_dict[keys].shape) )

# %%
max_abs_ind
# Out:
# [(2, 1),
#  (1, 1),
#  (3, 1),
#  (1, 1),
#  (1, 1),
#  (2, 3),
#  (3, 1),
#  (0, 1),
#  (1, 0),
#  (1, 1),
#  (1, 1),
#  (1, 0),
#  (0, 3),
#  (1, 3),
#  (3, 1),
#  (1, 3),
#  (3, 1),
#  (1, 3),
#  (1, 0),
#  (3, 1),
#  (1, 3),
#  (3, 0),
#  (0, 3),
#  (2, 3),
#  (3, 0),
#  (0, 1),
#  (0, 0),
#  (0, 3),
#  (3, 1),
#  (1, 0),
#  (1, 0),
#  (3, 0),
#  (1, 1),
#  (0, 1),
#  (1, 3),
#  (2, 3),
#  (1, 3),
#  (2, 1),
#  (2, 3),
#  (0, 1),
#  (1, 2),
#  (1, 2),
#  (0, 1),
#  (0, 1),
#  (1, 0),
#  (2, 1),
#  (0, 0),
#  (3, 3),
#  (3, 3),
#  (2, 3),
#  (2, 3),
#  (1, 3),
#  (2, 3),
#  (0, 1),
#  (1, 1),
#  (1, 3),
#  (1, 3),
#  (0, 1),
#  (1, 3),
#  (0, 1),
#  (1, 2),
#  (1, 1),
#  (1, 1),
#  (3, 1),
#  (3, 0),
#  (1, 0),
#  (3, 1),
#  (1, 1),
#  (0, 1),
#  (1, 0),
#  (1, 3),
#  (3, 0),
#  (1, 0),
#  (1, 2),
#  (1, 1),
#  (0, 3),
#  (1, 1),
#  (3, 0),
#  (1, 0),
#  (3, 1),
#  (1, 3),
#  (1, 1),
#  (1, 1),
#  (2, 3),
#  (1, 3),
#  (1, 1),
#  (1, 1),
#  (1, 3),
#  (1, 1),
#  (1, 1),
# ...

# %%
max_min_regs
# Out:
# [(11493.439217272611, -12535.468564594757),
#  (11603.786179364835, -5783.133695988294),
#  (3855.7860502584685, -4441.757679944121),
#  (11300.4818030098, -5115.169339904468),
#  (17289.132226326383, -4665.426299318021),
#  (14716.737258096748, -6693.729313454058),
#  (5436.85944515454, -8829.609697844866),
#  (5436.610426002147, -18807.25652121924),
#  (11142.464699620725, -6492.452133330947),
#  (9919.531083473585, -5995.940560075292),
#  (15539.32677398906, -9851.026089992396),
#  (17585.134620337398, -11313.130442622838),
#  (8426.294524137853, -6318.193821114537),
#  (9565.462129524456, -7792.486029067858),
#  (12351.7681542688, -5516.10410301316),
#  (12961.996980849754, -7457.13921028203),
#  (7663.649620997136, -6481.772605955852),
#  (5882.237812741406, -5140.298639033121),
#  (6315.329710131204, -5410.351583890209),
#  (8411.155894436506, -7786.846434460605),
#  (5100.194475976895, -4659.9893591813925),
#  (7011.672372312375, -6391.096216583682),
# ...

# %%
max_abs_regs
# Out:
# [12535.468564594757,
#  11603.786179364835,
#  4441.757679944121,
#  11300.4818030098,
#  17289.132226326383,
#  14716.737258096748,
#  8829.609697844866,
#  18807.25652121924,
#  11142.464699620725,
#  9919.531083473585,
#  15539.32677398906,
#  17585.134620337398,
#  8426.294524137853,
#  9565.462129524456,
#  12351.7681542688,
#  12961.996980849754,
#  7663.649620997136,
#  5882.237812741406,
#  6315.329710131204,
#  8411.155894436506,
#  5100.194475976895,
#  7011.672372312375,
#  10124.3753858696,
#  4836.965397750264,
#  19911.28332939426,
#  15464.432569046288,
#  0.0,
#  6410.210874392538,
#  17655.08653336479,
#  8299.256530704886,
#  8550.453058113859,
#  20632.78156191335,
#  9182.424322817975,
#  7072.138827925853,
#  6612.648911197284,
#  14246.980381846688,
#  12267.8852585826,
#  11270.924128061177,
#  6082.211377624451,
#  5999.323821525533,
#  5483.740128554959,
#  15170.162422770847,
#  40675.03313025431,
#  14508.591503477697,
#  9704.9535691954,
# ...

# %%
df_max_abs_regs = pd.DataFrame(dict(pair = list(site_files.keys()), max_reg_val = max_abs_regs))

# %%
df_max_abs_regs
# Out:
#                    pair   max_reg_val
# 0    site_36-38.csv.npy  12535.468565
# 1      site_4-9.csv.npy  11603.786179
# 2    site_11-37.csv.npy   4441.757680
# 3     site_2-23.csv.npy  11300.481803
# 4    site_11-27.csv.npy  17289.132226
# ..                  ...           ...
# 775  site_14-23.csv.npy  11681.074672
# 776   site_7-37.csv.npy   9974.131920
# 777   site_5-12.csv.npy   7274.315062
# 778    site_7-8.csv.npy   5073.336456
# 779  site_23-33.csv.npy   6489.876235
#
# [780 rows x 2 columns]

# %%
max_regs_only=[]
for keys in regressions.keys():
    site_files[keys] = np.load(keys)
    max_regs_only.append(site_files[keys][0][1].max()) if site_files[keys][0][1].max() > abs(site_files[keys][0][1].min()) else max_regs_only.append(site_files[keys][0][1].min())

# %%
max_regs_only
# Out:
# [-12535.468564594757,
#  11603.786179364835,
#  -4441.757679944121,
#  11300.4818030098,
#  17289.132226326383,
#  14716.737258096748,
#  -8829.609697844866,
#  -18807.25652121924,
#  11142.464699620725,
#  9919.531083473585,
#  15539.32677398906,
#  17585.134620337398,
#  8426.294524137853,
#  9565.462129524456,
#  12351.7681542688,
#  12961.996980849754,
#  7663.649620997136,
#  5882.237812741406,
#  6315.329710131204,
#  8411.155894436506,
#  5100.194475976895,
#  7011.672372312375,
#  10124.3753858696,
#  -4836.965397750264,
#  19911.28332939426,
#  -15464.432569046288,
#  0.0,
#  6410.210874392538,
#  17655.08653336479,
#  8299.256530704886,
#  -8550.453058113859,
#  20632.78156191335,
#  -9182.424322817975,
#  7072.138827925853,
#  6612.648911197284,
#  14246.980381846688,
#  12267.8852585826,
#  11270.924128061177,
#  -6082.211377624451,
#  5999.323821525533,
#  -5483.740128554959,
#  15170.162422770847,
#  40675.03313025431,
#  14508.591503477697,
#  9704.9535691954,
# ...

# %%
test_d=new_dict['site_36-38.csv.npy']

# %%
np.argwhere(test_d == max_regs_only[0]) #this corresponds to the value -12535.46 in the 1st mtx
# Out:
# array([[2, 1]])

# %%
test_2=new_dict['site_11-37.csv.npy']

# %%
np.argwhere(test_2 == max_regs_only[2]) #this corresponds to the value -4441.75 in the 3rd mtx #yay
# Out:
# array([[3, 1]])

# %%
np.unravel_index(np.argmin(test_d, axis=None), test_d.shape) #argmin
# Out:
# (2, 1)

# %%
np.unravel_index(np.argmax(test_d, axis=None), test_d.shape)
# Out:
# (3, 1)

# %%
np.argmax((np.argmax(test_d, axis=None),abs(np.argmin(test_d, axis=None))), axis=None)
# Out:
# 0

# %%
max((np.argmax(test_d, axis=None),abs(np.argmin(test_d, axis=None))))
# Out:
# 13

# %%
test_d.max()
# Out:
# 11493.439217272611

# %%
test_d.min()
# Out:
# -12535.468564594757

# %%
(max((test_d.max()), abs((test_d.min()))))
# Out:
# 12535.468564594757

# %%
np.argwhere((max((test_d.max()), abs((test_d.min())))))
# Out:
# array([[0]])

# %%
np.unravel_index((max((test_d.max()), abs((test_d.min())))),test_d.shape)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-e35bffc4fa5b> in <module>
# ----> 1 np.unravel_index((max((test_d.max()), abs((test_d.min())))),test_d.shape)
#
# TypeError: Iterator operand 0 dtype could not be cast from dtype('float64') to dtype('int64') according to the rule 'same_kind'

# %%
np.unravel_index(max((np.argmax(test_d, axis=None),abs(np.argmin(test_d, axis=None)))), test_d.shape)
# Out:
# (3, 1)

# %%
test_d.tolist().index((max((test_d.max()), abs((test_d.min())))).all())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-100-9b34c17929f5> in <module>
# ----> 1 test_d.tolist().index((max((test_d.max()), abs((test_d.min())))).all())
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
#test_d.tolist() # Python list
max_val = max((test_d.max()), abs((test_d.min())))
i = test_d.tolist().index((max_val).any())
print(i)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-92-15d048059cd4> in <module>
#       1 #test_d.tolist() # Python list
#       2 max_val = max((test_d.max()), abs((test_d.min())))
# ----> 3 i = test_d.tolist().index((max_val).any())
#       4 print(i)
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
print(test_d[0],test_d[1],test_d[2],test_d[3])
print(test_d[2][1])
# Out:
# [ 2796.42508857 -3696.25922819   275.93213189 -1308.62502738] [-2469.56738749 10512.28715457 -1411.10267469 -1390.70283418] [  2704.71262268 -12535.46856459   1626.8986082    3457.85717279] [-4.85806052e+03  1.14934392e+04  2.35771863e+00 -3.00034139e+03]
# -12535.468564594757

# %%
print(test_d.shape[0])
print(test_d.shape[1])
# Out:
# 4
# 4

# %%
indices = []
for i in range(test_d.shape[0]):
    for j in range(test_d.shape[1]):
        if j>>i:
            if test_d[i][j] == max((test_d.max()), abs((test_d.min()))):
                indices.append((i, j, max((test_d.max()), abs((test_d.min())))))
                print(indices)
print(len(indices))
# Out:
# 0

# %%
len(new_dict)
# Out:
# 780

# %%
for i in range(len(max_regs_only)):
    for keys in new_dict.keys():
        #print(np.argwhere(new_dict[keys] == max_regs_only[i]))
        continue
    print(np.argwhere(new_dict[keys] == max_regs_only[i]))
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [[2 1]]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [[2 1]]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# [[2 1]]
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ...

# %%
for keys in new_dict.keys():
    for i in range(len(max_regs_only)):
        for j in range(len(new_dict)):
            while i < j:
                print(np.argwhere(new_dict[keys] == max_regs_only[i]))
# Out:
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# [[2 1]]
# ...

# %%
#need to get the indices of the max_regs_only values!!
#max_reg_indices=[]
max_reg_indices=np.empty((0, 2),float)
for keys in regressions.keys():
    site_files[keys] = np.load(keys)
    new_dict[keys] = site_files[keys][0][1]
    arr = np.argwhere(new_dict[keys] == max_regs_only[i] for i in range(len(max_regs_only)))
    max_reg_indices=np.append(max_reg_indices, [arr], axis=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-bf989dca8aee> in <module>
#       6     new_dict[keys] = site_files[keys][0][1]
#       7     arr = np.argwhere(new_dict[keys] == max_regs_only[i] for i in range(len(max_regs_only)))
# ----> 8     max_reg_indices=np.append(max_reg_indices, [arr], axis=0)
#
# ~/miniconda3/lib/python3.7/site-packages/numpy/lib/function_base.py in append(arr, values, axis)
#    4692         values = ravel(values)
#    4693         axis = arr.ndim-1
# -> 4694     return concatenate((arr, values), axis=axis)
#    4695
#    4696
#
# ValueError: all the input arrays must have same number of dimensions
